# %% [markdown]
# ### Aqui será o projeto em si

# %% [markdown]
# ## IMPORTS

# %%
import pandas as pd
import numpy as np

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %% [markdown]
# ##### =========================================================
# ##### 2. PIPELINE DE PRÉ-PROCESSAMENTO
# ##### Tema escolhido:
# ##### Regressão -> focus_index
# ##### Classificação -> exam_score binário
# ##### =========================================================

# %% [markdown]
# --- Resumo Numérico ---
#                        count  missing     mean      std   min   median     max
# age                   5000.0        0   20.520    2.870  16.0   20.000   25.00
# study_hours           5000.0        0    4.540    1.822   0.0    4.530   11.84
# self_study_hours      5000.0        0    2.479    1.178   0.0    2.480    7.41
# online_classes_hours  5000.0        0    2.012    0.984   0.0    2.010    6.00
# social_media_hours    4750.0      250    2.995    1.467   0.0    2.975    8.28
# gaming_hours          5000.0        0    1.565    1.111   0.0    1.490    5.64
# sleep_hours           5000.0        0    7.016    1.164   4.0    7.010   10.00
# screen_time_hours     4600.0      400    6.986    2.476   1.0    6.955   15.30
# exercise_minutes      5000.0        0   74.536   42.932   0.0   75.000  149.00
# caffeine_intake_mg    4500.0      500  251.127  143.810   0.0  251.000  499.00
# part_time_job         5000.0        0    0.498    0.500   0.0    0.000    1.00
# upcoming_deadline     5000.0        0    0.501    0.500   0.0    1.000    1.00
# mental_health_score   4250.0      750    5.505    2.866   1.0    6.000   10.00
